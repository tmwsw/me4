# %%
import pandas as pd

# Чтение файла Excel
df = pd.read_excel('Лист Microsoft Excel.xlsx')

# Сохранение в CSV с кодировкой UTF-8 и разделителем запятая
df.to_csv('Данные1.csv', index=False, encoding='utf-8', sep=',')

# %%
df
# Out:
#       annotation_id  annotator  \
# 0               NaN        NaN
# 1              31.0        1.0
# 2               NaN        NaN
# 3              32.0        1.0
# 4               NaN        NaN
# ...             ...        ...
# 4741         2224.0        1.0
# 4742            NaN        NaN
# 4743         2225.0        1.0
# 4744            NaN        NaN
# 4745         1914.0        1.0
#
#                                                 comment  \
# 0                                                   NaN
# 1                                               спасибо
# 2                                                   NaN
# 3                                              спасибо!
# 4                                                   NaN
# ...                                                 ...
# 4741          два дня мусоропровод. сегодня с утра тоже
# 4742                                                NaN
# 4743  отрегулировать дверь замки . для должного откр...
# 4744                                                NaN
# 4745                                 всё сделано хорошо
#
#                   created_at         id  lead_time  rating  \
# 0                        NaT        NaN        NaN     NaN
# 1    2025-05-09 19:15:44.417  2945792.0      2.665     5.0
# 2                        NaT        NaN        NaN     NaN
# 3    2025-05-09 19:15:47.352  3234340.0      2.090     5.0
# 4                        NaT        NaN        NaN     NaN
# ...                      ...        ...        ...     ...
# 4741 2025-05-10 19:24:54.891  3296403.0      3.019     5.0
# 4742                     NaT        NaN        NaN     NaN
# 4743 2025-05-10 19:25:04.491  3165822.0      8.399     5.0
# 4744                     NaT        NaN        NaN     NaN
# 4745 2025-05-10 18:46:01.799  2991660.0      1.569     5.0
#
#                                                taxonomy  \
# 0                                                   NaN
# 1                     [{"taxonomy":[["Вопрос решен"]]}]
# 2                                                   NaN
# 3                     [{"taxonomy":[["Вопрос решен"]]}]
# 4                                                   NaN
# ...                                                 ...
# 4741  [{"taxonomy":[["Не удовлетворен"],["Не понрави...
# 4742                                                NaN
# 4743                  [{"taxonomy":[["Вопрос решен"]]}]
# 4744                                                NaN
# 4745                  [{"taxonomy":[["Вопрос решен"]]}]
#
#                   updated_at  Вопрос решен  Качество выполненной работы  \
# 0                        NaT           NaN                          NaN
# 1    2025-05-09 19:15:44.417           NaN                          NaN
# 2                        NaT           NaN                          NaN
# 3    2025-05-09 19:15:47.352           NaN                          NaN
# 4                        NaT           NaN                          NaN
# ...                      ...           ...                          ...
# 4741 2025-05-10 19:24:54.891           NaN                          NaN
# 4742                     NaT           NaN                          NaN
# 4743 2025-05-10 19:25:04.491           NaN                          NaN
# 4744                     NaT           NaN                          NaN
# 4745 2025-05-10 18:46:01.799           NaN                          NaN
#
#       Компетентность работника в общение   Не удовлетворен  \
# 0                                     NaN              NaN
# 1                                     NaN              NaN
# 2                                     NaN              NaN
# 3                                     NaN              NaN
# 4                                     NaN              NaN
# ...                                   ...              ...
# 4741                                  NaN              NaN
# 4742                                  NaN              NaN
# 4743                                  NaN              NaN
# 4744                                  NaN              NaN
# 4745                                  NaN              NaN
#
#       Скорость выполненной работы  Скорость ответа работника после запроса  \
# 0                             NaN                                      NaN
# 1                             NaN                                      NaN
# 2                             NaN                                      NaN
# 3                             NaN                                      NaN
# 4                             NaN                                      NaN
# ...                           ...                                      ...
# 4741                          NaN                                      NaN
# 4742                          NaN                                      NaN
# 4743                          NaN                                      NaN
# 4744                          NaN                                      NaN
# 4745                          NaN                                      NaN
#
#       Не понравился результат  Не понравилось качество
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 4                         NaN                      NaN
# ...                       ...                      ...
# 4741                      NaN                      NaN
# 4742                      NaN                      NaN
# 4743                      NaN                      NaN
# 4744                      NaN                      NaN
# 4745                      NaN                      NaN
#
# [4746 rows x 17 columns]

# %%
df.drop('annotator', axis=1)
# Out:
#       annotation_id                                            comment  \
# 0               NaN                                                NaN
# 1              31.0                                            спасибо
# 2               NaN                                                NaN
# 3              32.0                                           спасибо!
# 4               NaN                                                NaN
# ...             ...                                                ...
# 4741         2224.0          два дня мусоропровод. сегодня с утра тоже
# 4742            NaN                                                NaN
# 4743         2225.0  отрегулировать дверь замки . для должного откр...
# 4744            NaN                                                NaN
# 4745         1914.0                                 всё сделано хорошо
#
#                   created_at         id  lead_time  rating  \
# 0                        NaT        NaN        NaN     NaN
# 1    2025-05-09 19:15:44.417  2945792.0      2.665     5.0
# 2                        NaT        NaN        NaN     NaN
# 3    2025-05-09 19:15:47.352  3234340.0      2.090     5.0
# 4                        NaT        NaN        NaN     NaN
# ...                      ...        ...        ...     ...
# 4741 2025-05-10 19:24:54.891  3296403.0      3.019     5.0
# 4742                     NaT        NaN        NaN     NaN
# 4743 2025-05-10 19:25:04.491  3165822.0      8.399     5.0
# 4744                     NaT        NaN        NaN     NaN
# 4745 2025-05-10 18:46:01.799  2991660.0      1.569     5.0
#
#                                                taxonomy  \
# 0                                                   NaN
# 1                     [{"taxonomy":[["Вопрос решен"]]}]
# 2                                                   NaN
# 3                     [{"taxonomy":[["Вопрос решен"]]}]
# 4                                                   NaN
# ...                                                 ...
# 4741  [{"taxonomy":[["Не удовлетворен"],["Не понрави...
# 4742                                                NaN
# 4743                  [{"taxonomy":[["Вопрос решен"]]}]
# 4744                                                NaN
# 4745                  [{"taxonomy":[["Вопрос решен"]]}]
#
#                   updated_at  Вопрос решен  Качество выполненной работы  \
# 0                        NaT           NaN                          NaN
# 1    2025-05-09 19:15:44.417           NaN                          NaN
# 2                        NaT           NaN                          NaN
# 3    2025-05-09 19:15:47.352           NaN                          NaN
# 4                        NaT           NaN                          NaN
# ...                      ...           ...                          ...
# 4741 2025-05-10 19:24:54.891           NaN                          NaN
# 4742                     NaT           NaN                          NaN
# 4743 2025-05-10 19:25:04.491           NaN                          NaN
# 4744                     NaT           NaN                          NaN
# 4745 2025-05-10 18:46:01.799           NaN                          NaN
#
#       Компетентность работника в общение   Не удовлетворен  \
# 0                                     NaN              NaN
# 1                                     NaN              NaN
# 2                                     NaN              NaN
# 3                                     NaN              NaN
# 4                                     NaN              NaN
# ...                                   ...              ...
# 4741                                  NaN              NaN
# 4742                                  NaN              NaN
# 4743                                  NaN              NaN
# 4744                                  NaN              NaN
# 4745                                  NaN              NaN
#
#       Скорость выполненной работы  Скорость ответа работника после запроса  \
# 0                             NaN                                      NaN
# 1                             NaN                                      NaN
# 2                             NaN                                      NaN
# 3                             NaN                                      NaN
# 4                             NaN                                      NaN
# ...                           ...                                      ...
# 4741                          NaN                                      NaN
# 4742                          NaN                                      NaN
# 4743                          NaN                                      NaN
# 4744                          NaN                                      NaN
# 4745                          NaN                                      NaN
#
#       Не понравился результат  Не понравилось качество
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 4                         NaN                      NaN
# ...                       ...                      ...
# 4741                      NaN                      NaN
# 4742                      NaN                      NaN
# 4743                      NaN                      NaN
# 4744                      NaN                      NaN
# 4745                      NaN                      NaN
#
# [4746 rows x 16 columns]

# %%
df_clear = df.dropna(how='all')

df_clear
# Out:
#       annotation_id  annotator  \
# 1              31.0        1.0
# 3              32.0        1.0
# 5              33.0        1.0
# 7              34.0        1.0
# 9              35.0        1.0
# ...             ...        ...
# 4737         2222.0        1.0
# 4739         2223.0        1.0
# 4741         2224.0        1.0
# 4743         2225.0        1.0
# 4745         1914.0        1.0
#
#                                                 comment  \
# 1                                               спасибо
# 3                                              спасибо!
# 5                                              Отлично
# 7          Благодарю за оперативное решение проблемы !
# 9                 Прекрасный специалист! Побольше таких
# ...                                                 ...
# 4737                                  долго, но приятно
# 4739  16.03.2024 г ребята установили кондиционер. ра...
# 4741          два дня мусоропровод. сегодня с утра тоже
# 4743  отрегулировать дверь замки . для должного откр...
# 4745                                 всё сделано хорошо
#
#                   created_at         id  lead_time  rating  \
# 1    2025-05-09 19:15:44.417  2945792.0      2.665     5.0
# 3    2025-05-09 19:15:47.352  3234340.0      2.090     5.0
# 5    2025-05-09 19:15:51.239  3380332.0      3.126     5.0
# 7    2025-05-09 19:15:54.868  3381812.0      2.768     5.0
# 9    2025-05-09 19:16:17.609  3461991.0     31.167     5.0
# ...                      ...        ...        ...     ...
# 4737 2025-05-10 19:24:22.077  3507812.0     14.719     5.0
# 4739 2025-05-10 19:24:51.099  3478532.0     28.008     5.0
# 4741 2025-05-10 19:24:54.891  3296403.0      3.019     5.0
# 4743 2025-05-10 19:25:04.491  3165822.0      8.399     5.0
# 4745 2025-05-10 18:46:01.799  2991660.0      1.569     5.0
#
#                                                taxonomy  \
# 1                     [{"taxonomy":[["Вопрос решен"]]}]
# 3                     [{"taxonomy":[["Вопрос решен"]]}]
# 5                     [{"taxonomy":[["Вопрос решен"]]}]
# 7     [{"taxonomy":[["Скорость выполненной работы"],...
# 9     [{"taxonomy":[["Качество выполненной работы"],...
# ...                                                 ...
# 4737  [{"taxonomy":[["Вопрос решен"],["Не понравилос...
# 4739  [{"taxonomy":[["Качество выполненной работы"],...
# 4741  [{"taxonomy":[["Не удовлетворен"],["Не понрави...
# 4743                  [{"taxonomy":[["Вопрос решен"]]}]
# 4745                  [{"taxonomy":[["Вопрос решен"]]}]
#
#                   updated_at  Вопрос решен  Качество выполненной работы  \
# 1    2025-05-09 19:15:44.417           NaN                          NaN
# 3    2025-05-09 19:15:47.352           NaN                          NaN
# 5    2025-05-09 19:15:51.239           NaN                          NaN
# 7    2025-05-09 19:15:54.868           NaN                          NaN
# 9    2025-05-10 15:46:20.786           NaN                          NaN
# ...                      ...           ...                          ...
# 4737 2025-05-10 19:24:22.077           NaN                          NaN
# 4739 2025-05-10 19:24:51.099           NaN                          NaN
# 4741 2025-05-10 19:24:54.891           NaN                          NaN
# 4743 2025-05-10 19:25:04.491           NaN                          NaN
# 4745 2025-05-10 18:46:01.799           NaN                          NaN
#
#       Компетентность работника в общение   Не удовлетворен  \
# 1                                     NaN              NaN
# 3                                     NaN              NaN
# 5                                     NaN              NaN
# 7                                     NaN              NaN
# 9                                     NaN              NaN
# ...                                   ...              ...
# 4737                                  NaN              NaN
# 4739                                  NaN              NaN
# 4741                                  NaN              NaN
# 4743                                  NaN              NaN
# 4745                                  NaN              NaN
#
#       Скорость выполненной работы  Скорость ответа работника после запроса  \
# 1                             NaN                                      NaN
# 3                             NaN                                      NaN
# 5                             NaN                                      NaN
# 7                             NaN                                      NaN
# 9                             NaN                                      NaN
# ...                           ...                                      ...
# 4737                          NaN                                      NaN
# 4739                          NaN                                      NaN
# 4741                          NaN                                      NaN
# 4743                          NaN                                      NaN
# 4745                          NaN                                      NaN
#
#       Не понравился результат  Не понравилось качество
# 1                         NaN                      NaN
# 3                         NaN                      NaN
# 5                         NaN                      NaN
# 7                         NaN                      NaN
# 9                         NaN                      NaN
# ...                       ...                      ...
# 4737                      NaN                      NaN
# 4739                      NaN                      NaN
# 4741                      NaN                      NaN
# 4743                      NaN                      NaN
# 4745                      NaN                      NaN
#
# [2373 rows x 17 columns]
